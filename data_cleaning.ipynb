# %% [markdown]
# # Used car prices - Autotrade

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Data source: https://www.autotrader.com.au/
# #### Scope: Perth WA, 25km radius from postcode 6000

# %%
# Import libraries
import numpy as np
import pandas as pd
from pathlib import Path
import numpy as np
import requests
import time
import json
import math

# Import the API key
from config import geoapify_key

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##### Load the data

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
df = pd.read_csv(Path('data_collection_output/output_from_1_to_251.csv'))

# Review the DataFrame
df.head()
# Out:
#    Year model                                     Car Spec Kilometres  \
# 0        2007  2007 Audi TT 8J Coupe 2dr S tronic 6sp 2.0T  104,108km
# 1        2019             2019 Hyundai I30 Active PD2 MY19   74,070km
# 2        2019             2019 Hyundai I30 Active PD2 MY19   66,975km
# 3        2019             2019 Hyundai I30 Active PD2 MY19   68,845km
# 4        2017     2017 Mitsubishi Triton GLX (4X4) MQ MY18  188,978km
#
#     Seller type    Price                  Transmission  \
# 0  Dealer: Used  $17,990  Sports Automatic Dual Clutch
# 1  Dealer: Used  $20,998                     Automatic
# 2  Dealer: Used  $21,998                     Automatic
# 3  Dealer: Used  $21,998                     Automatic
# 4  Dealer: Used  $24,750                     Automatic
#
#                     Body type         Drive type        Engine  \
# 0                           -                  -             -
# 1     HATCH, 4 Doors, 5 Seats  Front Wheel Drive    4 cyl, 2 L
# 2     HATCH, 4 Doors, 5 Seats  Front Wheel Drive    4 cyl, 2 L
# 3     HATCH, 4 Doors, 5 Seats  Front Wheel Drive    4 cyl, 2 L
# 4  Ute Tray, 4 Doors, 5 Seats                4x4  4 cyl, 2.4 L
#
#          Fuel type  ...        Make   Model                         Variant  \
# 0              NaN  ...        Audi      TT  8J Coupe 2dr S tronic 6sp 2.0T
# 1  Unleaded Petrol  ...     Hyundai     I30                          Active
# 2  Unleaded Petrol  ...     Hyundai     I30                          Active
# 3  Unleaded Petrol  ...     Hyundai     I30                          Active
# 4           Diesel  ...  Mitsubishi  Triton                       GLX (4X4)
#
#      Series Warranty when new (months) Warranty when new (kms)  \
# 0       NaN                        NaN                     NaN
# 1  PD2 MY19                       60.0                 999,000
# 2  PD2 MY19                       60.0                 999,000
# 3  PD2 MY19                       60.0                 999,000
# 4   MQ MY18                       60.0                 100,000
#
#    Service interval (months) Service interval (kms) Country of origin  \
# 0                        NaN                    NaN               NaN
# 1                       12.0                 15,000               NaN
# 2                       12.0                 15,000               NaN
# 3                       12.0                 15,000               NaN
# 4                       12.0                 15,000               NaN
#
#   Vehicle segment
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# ##### Clean the data

# %%
# Check initial data info types and null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5670 entries, 0 to 5669
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year model                   5670 non-null   int64
#  1   Car Spec                     5659 non-null   object
#  2   Kilometres                   5659 non-null   object
#  3   Seller type                  5659 non-null   object
#  4   Price                        5659 non-null   object
#  5   Transmission                 5659 non-null   object
#  6   Body type                    5659 non-null   object
#  7   Drive type                   5659 non-null   object
#  8   Engine                       5659 non-null   object
#  9   Fuel type                    5305 non-null   object
#  10  Fuel consumption             5659 non-null   object
#  11  Colour ext / int             5659 non-null   object
#  12  Registration                 5659 non-null   object
#  13  Rego expiry                  5659 non-null   object
#  14  VIN                          5659 non-null   object
#  15  Stock No                     5659 non-null   object
#  16  ANCAP Safety rating          0 non-null      float64
#  17  Green overall rating         5659 non-null   object
#  18  Dealer                       5659 non-null   object
#  19  Address                      5659 non-null   object
#  20  Seating capacity             5025 non-null   float64
#  21  Doors                        5033 non-null   float64
#  22  Front tyre size              5002 non-null   object
#  23  Front rim size               5025 non-null   object
#  24  Rear tyre size               5002 non-null   object
#  25  Rear rim size                5024 non-null   object
#  26  Injection / Carburation      0 non-null      float64
#  27  CC                           5030 non-null   float64
#  28  Number of cylinders          4961 non-null   float64
#  29  Front suspension             4962 non-null   object
#  30  Rear suspension              4962 non-null   object
#  31  Front brakes                 5002 non-null   object
#  32  Rear brakes                  5002 non-null   object
#  33  Fuel tank capacity           5025 non-null   float64
#  34  Valve gear type              5025 non-null   float64
#  35  Maximum torque               5659 non-null   object
#  36  Maximum power (kW)           5659 non-null   object
#  37  CO2 level (g/km)             4808 non-null   float64
#  38  Green house rating           5659 non-null   object
#  39  Overall HxWxL                5659 non-null   object
#  40  Ground clearance unladen     5659 non-null   object
#  41  Wheelbase                    5659 non-null   object
#  42  Kerb weight                  5659 non-null   object
#  43  Turning circle               5659 non-null   object
#  44  Rear track                   5659 non-null   object
#  45  Front track                  5659 non-null   object
#  46  Gross trailer weight braked  5659 non-null   object
#  47  Make                         5659 non-null   object
#  48  Model                        5659 non-null   object
#  49  Variant                      5402 non-null   object
#  50  Series                       4953 non-null   object
#  51  Warranty when new (months)   5025 non-null   float64
#  52  Warranty when new (kms)      5025 non-null   object
#  53  Service interval (months)    5002 non-null   float64
#  54  Service interval (kms)       5002 non-null   object
#  55  Country of origin            0 non-null      float64
#  56  Vehicle segment              0 non-null      float64
# dtypes: float64(13), int64(1), object(43)
# memory usage: 2.5+ MB

# %%
# Drop columns no needed
df_clean = df.drop(['Seller type', 'Engine', 'Registration', 'Rego expiry', 'Stock No', 'ANCAP Safety rating', 'Green overall rating', 'Front tyre size',
       'Front rim size', 'Rear tyre size', 'Rear rim size', 'Injection / Carburation','Front suspension', 'Rear suspension', 'Front brakes', 'Rear brakes',
       'CO2 level (g/km)', 'Green house rating', 'Overall HxWxL', 'Ground clearance unladen', 'Wheelbase', 'Turning circle', 'Rear track', 'Front track',
       'Gross trailer weight braked', 'Series', 'Warranty when new (months)', 'Warranty when new (kms)', 'Service interval (months)', 'Service interval (kms)',
       'Country of origin', 'Vehicle segment'], axis=1)

df_clean.head()
# Out:
#    Year model                                     Car Spec Kilometres  \
# 0        2007  2007 Audi TT 8J Coupe 2dr S tronic 6sp 2.0T  104,108km
# 1        2019             2019 Hyundai I30 Active PD2 MY19   74,070km
# 2        2019             2019 Hyundai I30 Active PD2 MY19   66,975km
# 3        2019             2019 Hyundai I30 Active PD2 MY19   68,845km
# 4        2017     2017 Mitsubishi Triton GLX (4X4) MQ MY18  188,978km
#
#      Price                  Transmission                   Body type  \
# 0  $17,990  Sports Automatic Dual Clutch                           -
# 1  $20,998                     Automatic     HATCH, 4 Doors, 5 Seats
# 2  $21,998                     Automatic     HATCH, 4 Doors, 5 Seats
# 3  $21,998                     Automatic     HATCH, 4 Doors, 5 Seats
# 4  $24,750                     Automatic  Ute Tray, 4 Doors, 5 Seats
#
#           Drive type        Fuel type Fuel consumption Colour ext / int  ...  \
# 0                  -              NaN                -         Blue / -  ...
# 1  Front Wheel Drive  Unleaded Petrol  7.40 L / 100 km       Silver / -  ...
# 2  Front Wheel Drive  Unleaded Petrol  7.40 L / 100 km       Silver / -  ...
# 3  Front Wheel Drive  Unleaded Petrol  7.40 L / 100 km       Silver / -  ...
# 4                4x4           Diesel  7.60 L / 100 km    White / Black  ...
#
#        CC Number of cylinders Fuel tank capacity  Valve gear type  \
# 0     NaN                 NaN                NaN              NaN
# 1  1999.0                 4.0               50.0             16.0
# 2  1999.0                 4.0               50.0             16.0
# 3  1999.0                 4.0               50.0             16.0
# 4  2440.0                 4.0               75.0             16.0
#
#    Maximum torque  Maximum power (kW)  Kerb weight        Make   Model  \
# 0               -                   -            -        Audi      TT
# 1  203 @ 4700 RPM      120 @ 6200 RPM      1276 kg     Hyundai     I30
# 2  203 @ 4700 RPM      120 @ 6200 RPM      1276 kg     Hyundai     I30
# 3  203 @ 4700 RPM      120 @ 6200 RPM      1276 kg     Hyundai     I30
# 4  430 @ 2500 RPM      133 @ 3500 RPM      1930 kg  Mitsubishi  Triton
#
#                           Variant
# 0  8J Coupe 2dr S tronic 6sp 2.0T
# 1                          Active
# 2                          Active
# 3                          Active
# 4                       GLX (4X4)
#
# [5 rows x 25 columns]

# %%
# Drop null rows and duplicates
df_clean = df_clean.drop_duplicates(subset="VIN")
df_clean = df_clean.dropna()
df_clean.head()
# Out:
#    Year model                                  Car Spec Kilometres    Price  \
# 1        2019          2019 Hyundai I30 Active PD2 MY19   74,070km  $20,998
# 2        2019          2019 Hyundai I30 Active PD2 MY19   66,975km  $21,998
# 3        2019          2019 Hyundai I30 Active PD2 MY19   68,845km  $21,998
# 4        2017  2017 Mitsubishi Triton GLX (4X4) MQ MY18  188,978km  $24,750
# 5        2016  2016 Mitsubishi Triton GLX (4X4) MQ MY16  141,855km  $26,900
#
#   Transmission                   Body type         Drive type  \
# 1    Automatic     HATCH, 4 Doors, 5 Seats  Front Wheel Drive
# 2    Automatic     HATCH, 4 Doors, 5 Seats  Front Wheel Drive
# 3    Automatic     HATCH, 4 Doors, 5 Seats  Front Wheel Drive
# 4    Automatic  Ute Tray, 4 Doors, 5 Seats                4x4
# 5    Automatic  Ute Tray, 4 Doors, 5 Seats                4x4
#
#          Fuel type Fuel consumption Colour ext / int  ...      CC  \
# 1  Unleaded Petrol  7.40 L / 100 km       Silver / -  ...  1999.0
# 2  Unleaded Petrol  7.40 L / 100 km       Silver / -  ...  1999.0
# 3  Unleaded Petrol  7.40 L / 100 km       Silver / -  ...  1999.0
# 4           Diesel  7.60 L / 100 km    White / Black  ...  2440.0
# 5           Diesel  7.60 L / 100 km    White / Black  ...  2440.0
#
#   Number of cylinders Fuel tank capacity  Valve gear type  Maximum torque  \
# 1                 4.0               50.0             16.0  203 @ 4700 RPM
# 2                 4.0               50.0             16.0  203 @ 4700 RPM
# 3                 4.0               50.0             16.0  203 @ 4700 RPM
# 4                 4.0               75.0             16.0  430 @ 2500 RPM
# 5                 4.0               75.0             16.0  430 @ 2500 RPM
#
#    Maximum power (kW)  Kerb weight        Make   Model    Variant
# 1      120 @ 6200 RPM      1276 kg     Hyundai     I30     Active
# 2      120 @ 6200 RPM      1276 kg     Hyundai     I30     Active
# 3      120 @ 6200 RPM      1276 kg     Hyundai     I30     Active
# 4      133 @ 3500 RPM      1930 kg  Mitsubishi  Triton  GLX (4X4)
# 5      133 @ 3500 RPM      1930 kg  Mitsubishi  Triton  GLX (4X4)
#
# [5 rows x 25 columns]

# %%
# Check data info
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2163 entries, 1 to 5669
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year model           2163 non-null   int64
#  1   Car Spec             2163 non-null   object
#  2   Kilometres           2163 non-null   object
#  3   Price                2163 non-null   object
#  4   Transmission         2163 non-null   object
#  5   Body type            2163 non-null   object
#  6   Drive type           2163 non-null   object
#  7   Fuel type            2163 non-null   object
#  8   Fuel consumption     2163 non-null   object
#  9   Colour ext / int     2163 non-null   object
#  10  VIN                  2163 non-null   object
#  11  Dealer               2163 non-null   object
#  12  Address              2163 non-null   object
#  13  Seating capacity     2163 non-null   float64
#  14  Doors                2163 non-null   float64
#  15  CC                   2163 non-null   float64
#  16  Number of cylinders  2163 non-null   float64
#  17  Fuel tank capacity   2163 non-null   float64
#  18  Valve gear type      2163 non-null   float64
#  19  Maximum torque       2163 non-null   object
#  20  Maximum power (kW)   2163 non-null   object
#  21  Kerb weight          2163 non-null   object
#  22  Make                 2163 non-null   object
#  23  Model                2163 non-null   object
#  24  Variant              2163 non-null   object
# dtypes: float64(6), int64(1), object(18)
# memory usage: 439.4+ KB

# %%
# Convert Kilometres and price to integer
df_clean['Kilometres'] = pd.to_numeric(df_clean['Kilometres'].str.replace(',', '').str.replace('km', ''), errors='coerce')
df_clean['Price'] = pd.to_numeric(df_clean['Price'].str.replace('$', '').str.replace(',', ''), errors='coerce')
df_clean.head()
# Out:
#    Year model                                  Car Spec  Kilometres  Price  \
# 1        2019          2019 Hyundai I30 Active PD2 MY19     74070.0  20998
# 2        2019          2019 Hyundai I30 Active PD2 MY19     66975.0  21998
# 3        2019          2019 Hyundai I30 Active PD2 MY19     68845.0  21998
# 4        2017  2017 Mitsubishi Triton GLX (4X4) MQ MY18    188978.0  24750
# 5        2016  2016 Mitsubishi Triton GLX (4X4) MQ MY16    141855.0  26900
#
#   Transmission                   Body type         Drive type  \
# 1    Automatic     HATCH, 4 Doors, 5 Seats  Front Wheel Drive
# 2    Automatic     HATCH, 4 Doors, 5 Seats  Front Wheel Drive
# 3    Automatic     HATCH, 4 Doors, 5 Seats  Front Wheel Drive
# 4    Automatic  Ute Tray, 4 Doors, 5 Seats                4x4
# 5    Automatic  Ute Tray, 4 Doors, 5 Seats                4x4
#
#          Fuel type Fuel consumption Colour ext / int  ...      CC  \
# 1  Unleaded Petrol  7.40 L / 100 km       Silver / -  ...  1999.0
# 2  Unleaded Petrol  7.40 L / 100 km       Silver / -  ...  1999.0
# 3  Unleaded Petrol  7.40 L / 100 km       Silver / -  ...  1999.0
# 4           Diesel  7.60 L / 100 km    White / Black  ...  2440.0
# 5           Diesel  7.60 L / 100 km    White / Black  ...  2440.0
#
#   Number of cylinders Fuel tank capacity  Valve gear type  Maximum torque  \
# 1                 4.0               50.0             16.0  203 @ 4700 RPM
# 2                 4.0               50.0             16.0  203 @ 4700 RPM
# 3                 4.0               50.0             16.0  203 @ 4700 RPM
# 4                 4.0               75.0             16.0  430 @ 2500 RPM
# 5                 4.0               75.0             16.0  430 @ 2500 RPM
#
#    Maximum power (kW)  Kerb weight        Make   Model    Variant
# 1      120 @ 6200 RPM      1276 kg     Hyundai     I30     Active
# 2      120 @ 6200 RPM      1276 kg     Hyundai     I30     Active
# 3      120 @ 6200 RPM      1276 kg     Hyundai     I30     Active
# 4      133 @ 3500 RPM      1930 kg  Mitsubishi  Triton  GLX (4X4)
# 5      133 @ 3500 RPM      1930 kg  Mitsubishi  Triton  GLX (4X4)
#
# [5 rows x 25 columns]

# %%
# Validate for null values found in the previous result
print(df_clean['Kilometres'].isnull().value_counts())
print(df_clean['Price'].isnull().value_counts())
# Out:
# False    2158
# True        5
# Name: Kilometres, dtype: int64
# False    2163
# Name: Price, dtype: int64

# %%
# Drop the null values
df_clean.dropna(inplace=True)

# %%
# Check data info
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2158 entries, 1 to 5669
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year model           2158 non-null   int64
#  1   Car Spec             2158 non-null   object
#  2   Kilometres           2158 non-null   float64
#  3   Price                2158 non-null   int64
#  4   Transmission         2158 non-null   object
#  5   Body type            2158 non-null   object
#  6   Drive type           2158 non-null   object
#  7   Fuel type            2158 non-null   object
#  8   Fuel consumption     2158 non-null   object
#  9   Colour ext / int     2158 non-null   object
#  10  VIN                  2158 non-null   object
#  11  Dealer               2158 non-null   object
#  12  Address              2158 non-null   object
#  13  Seating capacity     2158 non-null   float64
#  14  Doors                2158 non-null   float64
#  15  CC                   2158 non-null   float64
#  16  Number of cylinders  2158 non-null   float64
#  17  Fuel tank capacity   2158 non-null   float64
#  18  Valve gear type      2158 non-null   float64
#  19  Maximum torque       2158 non-null   object
#  20  Maximum power (kW)   2158 non-null   object
#  21  Kerb weight          2158 non-null   object
#  22  Make                 2158 non-null   object
#  23  Model                2158 non-null   object
#  24  Variant              2158 non-null   object
# dtypes: float64(7), int64(2), object(16)
# memory usage: 438.3+ KB

# %%
# Check transmission value counts to do binning of small values
df_clean['Transmission'].value_counts()
# Out:
# Automatic                  1093
# Continuous Variable         344
# Manual                      305
# Auto Dual Clutch             93
# Auto Direct Shift            62
# Auto Seq Sportshift          33
# CVT Auto Sequential          31
# Direct Shift                 26
# Auto Sequential              20
# Auto D/SH T/Tron Spt         15
# Auto Sports Mode             15
# Auto SEQ Sports Mode         13
# Automated Manual             11
# Automatic G-Tronic            9
# Automatic Tiptronic           9
# Sequential Auto               9
# Auto Activematic              9
# -                             6
# Manual 4x4                    6
# Automatic Geartronic          6
# Auto S-Tronic                 6
# Auto Elec Sportshift          5
# Auto Steptronic Sport         5
# Auto Active Sequential        5
# CVT Multitronic               3
# Auto Sports Shift             3
# Automatic 4x4                 3
# Automatic Tipshift            2
# Auto Steptronic               2
# Electronic Automatic          2
# Automatic Steptronic          1
# Auto Tiptronic S              1
# Auto Selectronic              1
# Auto Dual Clutch Sports       1
# Auto Touchtronic              1
# Manual + Double O/D           1
# Automatic Sequential          1
# Name: Transmission, dtype: int64

# %%
# Binning transmission values based on "Auto|Automatic" and "Manual"
df_clean.loc[df_clean['Transmission'].str.contains('auto|automatic', case=False), 'Transmission'] = 'Automatic'
df_clean.loc[df_clean['Transmission'].str.contains('manual', case=False), 'Transmission'] = 'Manual'
df_clean['Transmission'].value_counts()
# Out:
# Automatic              1467
# Continuous Variable     344
# Manual                  312
# Direct Shift             26
# -                         6
# CVT Multitronic           3
# Name: Transmission, dtype: int64

# %%
# Binning transmission values for items < 300
transmission = df_clean['Transmission'].value_counts()
transmission_replace = list(transmission[transmission < 300].index)

for trans in transmission_replace:
    df_clean['Transmission'] = df_clean['Transmission'].replace(trans,"Other")

df_clean['Transmission'].value_counts()
# Out:
# Automatic              1467
# Continuous Variable     344
# Manual                  312
# Other                    35
# Name: Transmission, dtype: int64

# %%
# Validate for null values found in the previous result
print(df_clean['Transmission'].isnull().value_counts())
# Out:
# False    2158
# Name: Transmission, dtype: int64

# %%
# Extract the body type only and rmeove seats and doors, and adjust capital letters
df_clean['Body type'] = df_clean['Body type'].str.split(',').str[0].str.strip()
df_clean['Body type'] = df_clean['Body type'].str.lower().str.capitalize()
body_type = df_clean['Body type'].value_counts()
body_type
# Out:
# Suv             944
# Ute tray        424
# Hatch           386
# Sedan           230
# Wagon           103
# Commercial       29
# Coupe            28
# Convertible       8
# People mover      5
# Other             1
# Name: Body type, dtype: int64

# %%
# Binning the body types < 20
body_type_replace = list(body_type[body_type < 20].index)

for body in body_type_replace:
    df_clean['Body type'] = df_clean['Body type'].replace(body,"Other")

df_clean['Body type'].value_counts()
# Out:
# Suv           944
# Ute tray      424
# Hatch         386
# Sedan         230
# Wagon         103
# Commercial     29
# Coupe          28
# Other          14
# Name: Body type, dtype: int64

# %%
# Execute value counts for Fuel type for binning
fuel_type = df_clean['Fuel type'].value_counts()
fuel_type
# Out:
# Unleaded Petrol              927
# Diesel                       788
# Premium Unleaded Petrol      372
# Unleaded Petrol/Electric      48
# Premium Unleaded/Electric     20
# Diesel/Electric                1
# Liquid Petroleum Gas           1
# Electric/Pulp                  1
# Name: Fuel type, dtype: int64

# %%
# Binning the fuel type < 300
fuel_type_replace = list(fuel_type[fuel_type < 130].index)

for fuel in fuel_type_replace:
    df_clean['Fuel type'] = df_clean['Fuel type'].replace(fuel,"Other")

df_clean['Fuel type'].value_counts()
# Out:
# Unleaded Petrol            927
# Diesel                     788
# Premium Unleaded Petrol    372
# Other                       71
# Name: Fuel type, dtype: int64

# %%
# Validate for null values found in the previous result
print(df_clean['Fuel type'].isnull().value_counts())
# Out:
# False    2158
# Name: Fuel type, dtype: int64

# %%
# Adjust drive type to change Four Wheel Drive to 4x4
df_clean['Drive type'] = df_clean['Drive type'].replace('4x4', 'Four Wheel Drive')
df_clean['Drive type'] = df_clean['Drive type'].replace('4x2', 'Rear Wheel Drive')
df_clean['Drive type'].value_counts()
# Out:
# Front Wheel Drive    893
# Four Wheel Drive     617
# All Wheel Drive      397
# Rear Wheel Drive     251
# Name: Drive type, dtype: int64

# %%
# Validate for null values found in the previous result
print(df_clean['Drive type'].isnull().value_counts())
# Out:
# False    2158
# Name: Drive type, dtype: int64

# %%
# Extract the fuel consumption liters part
df_clean['Fuel consumption'] = df_clean['Fuel consumption'].str.extract(r'^(\d+(\.\d+)?)\s').astype('float64')
df_clean = df_clean.rename(columns={'Fuel consumption': 'Fuel consumption per 100km'})
df_clean.head()
# Out:
#    Year model                                  Car Spec  Kilometres  Price  \
# 1        2019          2019 Hyundai I30 Active PD2 MY19     74070.0  20998
# 2        2019          2019 Hyundai I30 Active PD2 MY19     66975.0  21998
# 3        2019          2019 Hyundai I30 Active PD2 MY19     68845.0  21998
# 4        2017  2017 Mitsubishi Triton GLX (4X4) MQ MY18    188978.0  24750
# 5        2016  2016 Mitsubishi Triton GLX (4X4) MQ MY16    141855.0  26900
#
#   Transmission Body type         Drive type        Fuel type  \
# 1    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 2    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 3    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 4    Automatic  Ute tray   Four Wheel Drive           Diesel
# 5    Automatic  Ute tray   Four Wheel Drive           Diesel
#
#    Fuel consumption per 100km Colour ext / int  ...      CC  \
# 1                         7.4       Silver / -  ...  1999.0
# 2                         7.4       Silver / -  ...  1999.0
# 3                         7.4       Silver / -  ...  1999.0
# 4                         7.6    White / Black  ...  2440.0
# 5                         7.6    White / Black  ...  2440.0
#
#   Number of cylinders Fuel tank capacity  Valve gear type  Maximum torque  \
# 1                 4.0               50.0             16.0  203 @ 4700 RPM
# 2                 4.0               50.0             16.0  203 @ 4700 RPM
# 3                 4.0               50.0             16.0  203 @ 4700 RPM
# 4                 4.0               75.0             16.0  430 @ 2500 RPM
# 5                 4.0               75.0             16.0  430 @ 2500 RPM
#
#    Maximum power (kW)  Kerb weight        Make   Model    Variant
# 1      120 @ 6200 RPM      1276 kg     Hyundai     I30     Active
# 2      120 @ 6200 RPM      1276 kg     Hyundai     I30     Active
# 3      120 @ 6200 RPM      1276 kg     Hyundai     I30     Active
# 4      133 @ 3500 RPM      1930 kg  Mitsubishi  Triton  GLX (4X4)
# 5      133 @ 3500 RPM      1930 kg  Mitsubishi  Triton  GLX (4X4)
#
# [5 rows x 25 columns]

# %%
# Validate for null values found in the previous result
print(df_clean['Fuel consumption per 100km'].isnull().value_counts())
# Out:
# False    2158
# Name: Fuel consumption per 100km, dtype: int64

# %%
# Adjust colour coloumn to only ext colour
df_clean['Colour ext / int'] = df_clean['Colour ext / int'].str.split().str[0]
df_clean = df_clean.rename(columns={'Colour ext / int': 'Colour ext'})
colour_ext = df_clean['Colour ext'].value_counts()
colour_ext
# Out:
# White       923
# Silver      308
# Grey        293
# Black       195
# Blue        190
# Red         132
# Green        24
# -            23
# Brown        21
# Orange       20
# Gold         12
# Yellow       10
# Beige         5
# Burgundy      2
# Name: Colour ext, dtype: int64

# %%
# Binning the colours < 130
colour_ext_replace = list(colour_ext[colour_ext < 130].index)

for colour in colour_ext_replace:
    df_clean['Colour ext'] = df_clean['Colour ext'].replace(colour,"Other")

df_clean['Colour ext'].value_counts()
# Out:
# White     923
# Silver    308
# Grey      293
# Black     195
# Blue      190
# Red       132
# Other     117
# Name: Colour ext, dtype: int64

# %%
# Validate for null values found in the previous result
print(df_clean['Colour ext'].isnull().value_counts())
# Out:
# False    2158
# Name: Colour ext, dtype: int64

# %%
# Check datatypes
df_clean.dtypes
# Out:
# Year model                      int64
# Car Spec                       object
# Kilometres                    float64
# Price                           int64
# Transmission                   object
# Body type                      object
# Drive type                     object
# Fuel type                      object
# Fuel consumption per 100km    float64
# Colour ext                     object
# VIN                            object
# Dealer                         object
# Address                        object
# Seating capacity              float64
# Doors                         float64
# CC                            float64
# Number of cylinders           float64
# Fuel tank capacity            float64
# Valve gear type               float64
# Maximum torque                 object
# Maximum power (kW)             object
# Kerb weight                    object
# Make                           object
# Model                          object
# Variant                        object
# dtype: object

# %%
# Change datatypes of some numerical columns from float to integers
columns_to_convert = ['Kilometres', 'Seating capacity', 'Doors','CC', 'Number of cylinders', 'Fuel tank capacity', 'Valve gear type']
df_clean[columns_to_convert] = df_clean[columns_to_convert].astype('int64')
df_clean.dtypes
# Out:
# Year model                      int64
# Car Spec                       object
# Kilometres                      int64
# Price                           int64
# Transmission                   object
# Body type                      object
# Drive type                     object
# Fuel type                      object
# Fuel consumption per 100km    float64
# Colour ext                     object
# VIN                            object
# Dealer                         object
# Address                        object
# Seating capacity                int64
# Doors                           int64
# CC                              int64
# Number of cylinders             int64
# Fuel tank capacity              int64
# Valve gear type                 int64
# Maximum torque                 object
# Maximum power (kW)             object
# Kerb weight                    object
# Make                           object
# Model                          object
# Variant                        object
# dtype: object

# %%
# Validate for null values found in the previous result
print(df_clean.isnull().sum())
# Out:
# Year model                    0
# Car Spec                      0
# Kilometres                    0
# Price                         0
# Transmission                  0
# Body type                     0
# Drive type                    0
# Fuel type                     0
# Fuel consumption per 100km    0
# Colour ext                    0
# VIN                           0
# Dealer                        0
# Address                       0
# Seating capacity              0
# Doors                         0
# CC                            0
# Number of cylinders           0
# Fuel tank capacity            0
# Valve gear type               0
# Maximum torque                0
# Maximum power (kW)            0
# Kerb weight                   0
# Make                          0
# Model                         0
# Variant                       0
# dtype: int64

# %%
# From the Max Torque and Power, extract only the Peak torque (first value of Max Torque) and the Horse Power first value of Max Power converted from KW to HP)
df_clean['Maximum torque'] = df_clean['Maximum torque'].str.split().str[0]
df_clean = df_clean.rename(columns={'Maximum torque': 'Peak torque (Nm)'})
df_clean['Peak torque (Nm)'] = df_clean['Peak torque (Nm)'].astype('int64')

df_clean['Maximum power (kW)'] = df_clean['Maximum power (kW)'].str.split().str[0]
df_clean['Maximum power (kW)'] = pd.to_numeric(df_clean['Maximum power (kW)'], errors='coerce')

conversion_factor_kW_HP =  1.341
df_clean['Maximum power (kW)'] = df_clean['Maximum power (kW)'] * conversion_factor_kW_HP
df_clean = df_clean.rename(columns={'Maximum power (kW)': 'Horsepower'})
df_clean['Horsepower'] = df_clean['Horsepower'].apply(math.ceil)

df_clean.head()
# Out:
#    Year model                                  Car Spec  Kilometres  Price  \
# 1        2019          2019 Hyundai I30 Active PD2 MY19       74070  20998
# 2        2019          2019 Hyundai I30 Active PD2 MY19       66975  21998
# 3        2019          2019 Hyundai I30 Active PD2 MY19       68845  21998
# 4        2017  2017 Mitsubishi Triton GLX (4X4) MQ MY18      188978  24750
# 5        2016  2016 Mitsubishi Triton GLX (4X4) MQ MY16      141855  26900
#
#   Transmission Body type         Drive type        Fuel type  \
# 1    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 2    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 3    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 4    Automatic  Ute tray   Four Wheel Drive           Diesel
# 5    Automatic  Ute tray   Four Wheel Drive           Diesel
#
#    Fuel consumption per 100km Colour ext  ...    CC Number of cylinders  \
# 1                         7.4     Silver  ...  1999                   4
# 2                         7.4     Silver  ...  1999                   4
# 3                         7.4     Silver  ...  1999                   4
# 4                         7.6      White  ...  2440                   4
# 5                         7.6      White  ...  2440                   4
#
#   Fuel tank capacity  Valve gear type  Peak torque (Nm)  Horsepower  \
# 1                 50               16               203         161
# 2                 50               16               203         161
# 3                 50               16               203         161
# 4                 75               16               430         179
# 5                 75               16               430         179
#
#    Kerb weight        Make   Model    Variant
# 1      1276 kg     Hyundai     I30     Active
# 2      1276 kg     Hyundai     I30     Active
# 3      1276 kg     Hyundai     I30     Active
# 4      1930 kg  Mitsubishi  Triton  GLX (4X4)
# 5      1930 kg  Mitsubishi  Triton  GLX (4X4)
#
# [5 rows x 25 columns]

# %%
# Validate for null values found in the previous result
print(df_clean['Peak torque (Nm)'].isnull().value_counts())
print(df_clean['Horsepower'].isnull().value_counts())
# Out:
# False    2158
# Name: Peak torque (Nm), dtype: int64
# False    2158
# Name: Horsepower, dtype: int64

# %%
# Convert Kerb weight from string to integer
df_clean['Kerb weight'] = df_clean['Kerb weight'].str.split().str[0]
df_clean['Kerb weight'] = pd.to_numeric(df_clean['Kerb weight'], errors='coerce')
df_clean['Kerb weight'] = df_clean['Kerb weight'].astype('Int64')
df_clean.head()
# Out:
#    Year model                                  Car Spec  Kilometres  Price  \
# 1        2019          2019 Hyundai I30 Active PD2 MY19       74070  20998
# 2        2019          2019 Hyundai I30 Active PD2 MY19       66975  21998
# 3        2019          2019 Hyundai I30 Active PD2 MY19       68845  21998
# 4        2017  2017 Mitsubishi Triton GLX (4X4) MQ MY18      188978  24750
# 5        2016  2016 Mitsubishi Triton GLX (4X4) MQ MY16      141855  26900
#
#   Transmission Body type         Drive type        Fuel type  \
# 1    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 2    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 3    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 4    Automatic  Ute tray   Four Wheel Drive           Diesel
# 5    Automatic  Ute tray   Four Wheel Drive           Diesel
#
#    Fuel consumption per 100km Colour ext  ...    CC Number of cylinders  \
# 1                         7.4     Silver  ...  1999                   4
# 2                         7.4     Silver  ...  1999                   4
# 3                         7.4     Silver  ...  1999                   4
# 4                         7.6      White  ...  2440                   4
# 5                         7.6      White  ...  2440                   4
#
#   Fuel tank capacity  Valve gear type  Peak torque (Nm)  Horsepower  \
# 1                 50               16               203         161
# 2                 50               16               203         161
# 3                 50               16               203         161
# 4                 75               16               430         179
# 5                 75               16               430         179
#
#    Kerb weight        Make   Model    Variant
# 1         1276     Hyundai     I30     Active
# 2         1276     Hyundai     I30     Active
# 3         1276     Hyundai     I30     Active
# 4         1930  Mitsubishi  Triton  GLX (4X4)
# 5         1930  Mitsubishi  Triton  GLX (4X4)
#
# [5 rows x 25 columns]

# %%
# Validate for null values found in the previous result
print(df_clean['Kerb weight'].isnull().value_counts())
# Out:
# False    2156
# True        2
# Name: Kerb weight, dtype: int64

# %%
# Drop the null values
df_clean.dropna(inplace=True)

# %%
# Last drop of rows where values are "0" and any value wih "-"
df_clean = df_clean.loc[(df_clean != 0).all(axis=1)]
df_clean = df_clean.replace("-", float("nan")).dropna()
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2126 entries, 1 to 5669
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year model                  2126 non-null   int64
#  1   Car Spec                    2126 non-null   object
#  2   Kilometres                  2126 non-null   int64
#  3   Price                       2126 non-null   int64
#  4   Transmission                2126 non-null   object
#  5   Body type                   2126 non-null   object
#  6   Drive type                  2126 non-null   object
#  7   Fuel type                   2126 non-null   object
#  8   Fuel consumption per 100km  2126 non-null   float64
#  9   Colour ext                  2126 non-null   object
#  10  VIN                         2126 non-null   object
#  11  Dealer                      2126 non-null   object
#  12  Address                     2126 non-null   object
#  13  Seating capacity            2126 non-null   int64
#  14  Doors                       2126 non-null   int64
#  15  CC                          2126 non-null   int64
#  16  Number of cylinders         2126 non-null   int64
#  17  Fuel tank capacity          2126 non-null   int64
#  18  Valve gear type             2126 non-null   int64
#  19  Peak torque (Nm)            2126 non-null   int64
#  20  Horsepower                  2126 non-null   int64
#  21  Kerb weight                 2126 non-null   Int64
#  22  Make                        2126 non-null   object
#  23  Model                       2126 non-null   object
#  24  Variant                     2126 non-null   object
# dtypes: Int64(1), float64(1), int64(11), object(12)
# memory usage: 433.9+ KB

# %%
# Double checl for null values found in the previous data cleaning exercise
print(df_clean.isnull().sum())
# Out:
# Year model                    0
# Car Spec                      0
# Kilometres                    0
# Price                         0
# Transmission                  0
# Body type                     0
# Drive type                    0
# Fuel type                     0
# Fuel consumption per 100km    0
# Colour ext                    0
# VIN                           0
# Dealer                        0
# Address                       0
# Seating capacity              0
# Doors                         0
# CC                            0
# Number of cylinders           0
# Fuel tank capacity            0
# Valve gear type               0
# Peak torque (Nm)              0
# Horsepower                    0
# Kerb weight                   0
# Make                          0
# Model                         0
# Variant                       0
# dtype: int64

# %%
# Last check of all datatypes
df_clean.dtypes
# Out:
# Year model                      int64
# Car Spec                       object
# Kilometres                      int64
# Price                           int64
# Transmission                   object
# Body type                      object
# Drive type                     object
# Fuel type                      object
# Fuel consumption per 100km    float64
# Colour ext                     object
# VIN                            object
# Dealer                         object
# Address                        object
# Seating capacity                int64
# Doors                           int64
# CC                              int64
# Number of cylinders             int64
# Fuel tank capacity              int64
# Valve gear type                 int64
# Peak torque (Nm)                int64
# Horsepower                      int64
# Kerb weight                     Int64
# Make                           object
# Model                          object
# Variant                        object
# dtype: object

# %%
# Assign the new df_clean to a new variable and download a file to check all data is correct
df_car_listing = df_clean
df_car_listing.to_csv('data_cleaning_output/used_cars_dataset_test.csv', index=False)
print("Dataset test save: Completed")
# Out:
# Dataset test save: Completed

# %%
## Add columns to the df where by using the Geoapify API will fetch latitude and longitude
df_car_listing["lat"] = ""
df_car_listing["lon"] = ""
df_car_listing.head()
# Out:
#    Year model                                  Car Spec  Kilometres  Price  \
# 1        2019          2019 Hyundai I30 Active PD2 MY19       74070  20998
# 2        2019          2019 Hyundai I30 Active PD2 MY19       66975  21998
# 3        2019          2019 Hyundai I30 Active PD2 MY19       68845  21998
# 4        2017  2017 Mitsubishi Triton GLX (4X4) MQ MY18      188978  24750
# 5        2016  2016 Mitsubishi Triton GLX (4X4) MQ MY16      141855  26900
#
#   Transmission Body type         Drive type        Fuel type  \
# 1    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 2    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 3    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 4    Automatic  Ute tray   Four Wheel Drive           Diesel
# 5    Automatic  Ute tray   Four Wheel Drive           Diesel
#
#    Fuel consumption per 100km Colour ext  ... Fuel tank capacity  \
# 1                         7.4     Silver  ...                 50
# 2                         7.4     Silver  ...                 50
# 3                         7.4     Silver  ...                 50
# 4                         7.6      White  ...                 75
# 5                         7.6      White  ...                 75
#
#   Valve gear type Peak torque (Nm)  Horsepower  Kerb weight        Make  \
# 1              16              203         161         1276     Hyundai
# 2              16              203         161         1276     Hyundai
# 3              16              203         161         1276     Hyundai
# 4              16              430         179         1930  Mitsubishi
# 5              16              430         179         1930  Mitsubishi
#
#     Model    Variant  lat  lon
# 1     I30     Active
# 2     I30     Active
# 3     I30     Active
# 4  Triton  GLX (4X4)
# 5  Triton  GLX (4X4)
#
# [5 rows x 27 columns]

# %%
# Define the API parameters to get the Geoapify link
base_url = "https://api.geoapify.com/v1/geocode/search?"
params = {
    "apiKey": geoapify_key,
    "format": "json"
}

# %%
# Print a message to follow up the lat and lon search
print("Starting lat and lon search:")
print("----------------------------")

# Loop through the customers_df DataFrame and search coordinates for each customer
for i, row in df_car_listing.iterrows():
    params["text"] = f'{row["Address"]}'

    # Make the API request
    response = requests.get(base_url, params=params)

    # Convert reponse to JSON
    response = response.json()

    # Extract latitude and longitude
    lat = response["results"][0]["lat"]
    lon = response["results"][0]["lon"]

    # Add lat and lon to the customers_df DataFrame
    df_car_listing.loc[i, "lat"] = lat
    df_car_listing.loc[i, "lon"] = lon

    # Log the search results
    print(f"Coordinates for {row['Address']} fetched. Lat: {lat}, Lon: {lon}.")

# Display sample data to confirm that the coordinates appear
df_car_listing.head()
# Out:
# Starting lat and lon search:
# ----------------------------
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for 76 Division Street, Welshpool, WA fetched. Lat: -31.987188, Lon: 115.935923.
# Coordinates for 76 Division Street, Welshpool, WA fetched. Lat: -31.987188, Lon: 115.935923.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 76 Division Street, Welshpool, WA fetched. Lat: -31.987188, Lon: 115.935923.
# Coordinates for 464 Canning Highway, Como, WA fetched. Lat: -32.00604, Lon: 115.8597.
# Coordinates for 76 Division Street, Welshpool, WA fetched. Lat: -31.987188, Lon: 115.935923.
# Coordinates for 1093 Albany Highway, Bentley, WA fetched. Lat: -31.999547, Lon: 115.916029.
# Coordinates for 198 Collier Rd, Bayswater, WA fetched. Lat: -31.904689, Lon: 115.917071.
# Coordinates for 391 Guildford Road, Bayswater, WA fetched. Lat: -31.92562, Lon: 115.90992.
# Coordinates for 8 Parkland Road, Osborne Park, WA fetched. Lat: -31.91667, Lon: 115.817585.
# Coordinates for 76 Division Street, Welshpool, WA fetched. Lat: -31.987188, Lon: 115.935923.
# Coordinates for 76 Division Street, Welshpool, WA fetched. Lat: -31.987188, Lon: 115.935923.
# Coordinates for 8 Parkland Road, Osborne Park, WA fetched. Lat: -31.91667, Lon: 115.817585.
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for 20 Motor Parade, Wangara, WA fetched. Lat: -31.794136, Lon: 115.816569.
# Coordinates for 1 Lancaster Road, Wangara, WA fetched. Lat: -31.796743, Lon: 115.815802.
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for 76 Division Street, Welshpool, WA fetched. Lat: -31.987188, Lon: 115.935923.
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for 76 Division Street, Welshpool, WA fetched. Lat: -31.987188, Lon: 115.935923.
# Coordinates for 1787 Albany Highway, Kenwick, WA fetched. Lat: -32.04529, Lon: 115.97387.
# Coordinates for 8 Parkland Road, Osborne Park, WA fetched. Lat: -31.91667, Lon: 115.817585.
# Coordinates for 1 Lancaster Road, Wangara, WA fetched. Lat: -31.796743, Lon: 115.815802.
# Coordinates for 1787 Albany Highway, Kenwick, WA fetched. Lat: -32.04529, Lon: 115.97387.
# Coordinates for 1787 Albany Highway, Kenwick, WA fetched. Lat: -32.04529, Lon: 115.97387.
# Coordinates for 527 Newcastle Street, West Perth, WA fetched. Lat: -31.941255, Lon: 115.848861.
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for 527 Newcastle Street, West Perth, WA fetched. Lat: -31.941255, Lon: 115.848861.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 16 Baretta Road, Wangara, WA fetched. Lat: -31.79241, Lon: 115.82027.
# Coordinates for 1787 Albany Highway, Kenwick, WA fetched. Lat: -32.04529, Lon: 115.97387.
# Coordinates for 76 Division Street, Welshpool, WA fetched. Lat: -31.987188, Lon: 115.935923.
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for
# Coordinates for 8 Parkland Road, Osborne Park, WA fetched. Lat: -31.91667, Lon: 115.817585.
# Coordinates for 7 Pembroke Road, Wangara, WA fetched. Lat: -31.797369, Lon: 115.818506.
# Coordinates for 4 Christian Court, Bayswater, WA fetched. Lat: -31.90887, Lon: 115.91621.
# Coordinates for 545 Newcastle Street, West Perth, WA fetched. Lat: -31.94074, Lon: 115.84835.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 1787 Albany Highway, Kenwick, WA fetched. Lat: -32.04529, Lon: 115.97387.
# Coordinates for 8 Parkland Road, Osborne Park, WA fetched. Lat: -31.91667, Lon: 115.817585.
# Coordinates for 707 Albany Highway, East Victoria Park, WA fetched. Lat: -31.98209, Lon: 115.90096.
# Coordinates for 220 Newcastle Street, Northbridge, WA fetched. Lat: -31.9432313, Lon: 115.8544195.
# Coordinates for 435 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.90835, Lon: 115.8103.
# Coordinates for 133 Welshpool Road, Welshpool, WA fetched. Lat: -31.995224, Lon: 115.932444.
# Coordinates for 527 Newcastle Street, West Perth, WA fetched. Lat: -31.941255, Lon: 115.848861.
# Coordinates for 25 Prindiville Drive, Wangara, WA fetched. Lat: -31.79038, Lon: 115.81869.
# Coordinates for 209 Bannister Road, Canning Vale, WA fetched. Lat: -32.06485, Lon: 115.90025.
# Coordinates for 1735 Albany Highway, Kenwick, WA fetched. Lat: -32.0401613, Lon: 115.9709649.
# Coordinates for 41 Buckingham Drive, Wangara, WA fetched. Lat: -31.78645, Lon: 115.81995.
# Coordinates for 25 Guildford Road, Mount Lawley, WA fetched. Lat: -31.91463, Lon: 115.93485.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 1261 Albany Highway, Cannington, WA fetched. Lat: -32.012637, Lon: 115.926416.
# Coordinates for 133 Welshpool Road, Welshpool, WA fetched. Lat: -31.995224, Lon: 115.932444.
# Coordinates for 324 Collier Road, Bassendean, WA fetched. Lat: -31.906315, Lon: 115.932176.
# Coordinates for 468 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 4 Hocking Road, KINGSLEY, WA fetched. Lat: -31.80094, Lon: 115.81669.
# Coordinates for 391 Guildford Road, Bayswater, WA fetched. Lat: -31.92562, Lon: 115.90992.
# Coordinates for 1042 Albany Highway, Saint James, WA fetched. Lat: -31.996515, Lon: 115.914741.
# Coordinates for 474 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.90425, Lon: 115.80696.
# Coordinates for 20 Motor Parade, Wangara, WA fetched. Lat: -31.794136, Lon: 115.816569.
# Coordinates for 25 Prindiville Drive, Wangara, WA fetched. Lat: -31.79038, Lon: 115.81869.
# Coordinates for 3 Salpietro Street, Bibra Lake, WA fetched. Lat: -32.11556, Lon: 115.79544.
# Coordinates for 474 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.90425, Lon: 115.80696.
# Coordinates for 20 Motor Parade, Wangara, WA fetched. Lat: -31.794136, Lon: 115.816569.
# Coordinates for 1787 Albany Highway, Kenwick, WA fetched. Lat: -32.04529, Lon: 115.97387.
# Coordinates for 77 Buckingham Drive, Wangara, WA fetched. Lat: -31.78773, Lon: 115.82755.
# Coordinates for 133 Welshpool Road, Welshpool, WA fetched. Lat: -31.995224, Lon: 115.932444.
# Coordinates for 384 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for 69 Beechboro Road South, Bayswater, WA fetched. Lat: -31.91024, Lon: 115.91379.
# Coordinates for Albany Highway, Victoria Park, WA fetched. Lat: 47.431768, Lon: -122.227996.
# Coordinates for 1261 Albany Highway, Cannington, WA fetched. Lat: -32.012637, Lon: 115.926416.
# Coordinates for 25 Prindiville Drive, Wangara, WA fetched. Lat: -31.79038, Lon: 115.81869.
# Coordinates for 527 Newcastle Street, West Perth, WA fetched. Lat: -31.941255, Lon: 115.848861.
# Coordinates for 70-84 Collier Road, Morley, WA fetched. Lat: -31.900748, Lon: 115.903642.
# Coordinates for 1143 Albany Highway, Bentley, WA fetched. Lat: -32.00236, Lon: 115.91905.
# Coordinates for 3 Salpietro Street, Bibra Lake, WA fetched. Lat: -32.11556, Lon: 115.79544.
# Coordinates for 4 Chokolich Street, Wangara, WA fetched. Lat: -31.79018, Lon: 115.81566.
# Coordinates for 297 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.91454, Lon: 115.824791.
# Coordinates for 16 Baretta Road, Wangara, WA fetched. Lat: -31.79241, Lon: 115.82027.
# Coordinates for Albany Highway, Victoria Park, WA fetched. Lat: 47.431768, Lon: -122.227996.
# Coordinates for 16 Baretta Road, Wangara, WA fetched. Lat: -31.79241, Lon: 115.82027.
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 1/38 Prindiville Drive, Wangara, WA fetched. Lat: -31.79155, Lon: 115.82158.
# Coordinates for 101 Broun Avenue, Morley, WA fetched. Lat: -31.902026, Lon: 115.904008.
# Coordinates for 24 Automotive Drive, Wangara, WA fetched. Lat: -31.794357, Lon: 115.817341.
# Coordinates for 324 Collier Road, Bassendean, WA fetched. Lat: -31.906315, Lon: 115.932176.
# Coordinates for 37 Rockingham Road, Hamilton Hill, WA fetched. Lat: -32.08184, Lon: 115.7682.
# Coordinates for 464 Canning Highway, Como, WA fetched. Lat: -32.00604, Lon: 115.8597.
# Coordinates for 384 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.91151, Lon: 115.81708.
# Coordinates for 391 Guildford Road, Bayswater, WA fetched. Lat: -31.92562, Lon: 115.90992.
# Coordinates for 468 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 1261 Albany Highway, Cannington, WA fetched. Lat: -32.012637, Lon: 115.926416.
# Coordinates for 24 Automotive Drive, Wangara, WA fetched. Lat: -31.794357, Lon: 115.817341.
# Coordinates for 430 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.90779, Lon: 115.81192.
# Coordinates for 1324 Albany Highway, Cannington, WA fetched. Lat: -32.0166894, Lon: 115.9322155.
# Coordinates for 37 Rockingham Road, Hamilton Hill, WA fetched. Lat: -32.08184, Lon: 115.7682.
# Coordinates for 2 Joondalup Drive, Edgewater, WA fetched. Lat: -31.7572029, Lon: 115.7731046.
# Coordinates for 435 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.90835, Lon: 115.8103.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 6 Automotive Drive, Wangara, WA fetched. Lat: -31.794467, Lon: 115.815222.
# Coordinates for 198 Collier Rd, Bayswater, WA fetched. Lat: -31.904689, Lon: 115.917071.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 4 Hocking Road, KINGSLEY, WA fetched. Lat: -31.80094, Lon: 115.81669.
# Coordinates for 25 Prindiville Drive, Wangara, WA fetched. Lat: -31.79038, Lon: 115.81869.
# Coordinates for 1900 Albany Highway, Maddington, WA fetched. Lat: -32.05044, Lon: 115.983723.
# Coordinates for 32 Welshpool Rd, Welshpool, WA fetched. Lat: -31.99353, Lon: 115.91866.
# Coordinates for 468 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for
Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.90779, Lon: 115.81192.
# Coordinates for 133 Welshpool Road, Welshpool, WA fetched. Lat: -31.995224, Lon: 115.932444.
# Coordinates for 24 Automotive Drive, Wangara, WA fetched. Lat: -31.794357, Lon: 115.817341.
# Coordinates for 1042 Albany Highway, Saint James, WA fetched. Lat: -31.996515, Lon: 115.914741.
# Coordinates for 1093 Albany Highway, Bentley, WA fetched. Lat: -31.999547, Lon: 115.916029.
# Coordinates for 1308 Albany Highway, Cannington, WA fetched. Lat: -32.015497, Lon: 115.931154.
# Coordinates for 8 Parkland Road, Osborne Park, WA fetched. Lat: -31.91667, Lon: 115.817585.
# Coordinates for 16 Baretta Road, Wangara, WA fetched. Lat: -31.79241, Lon: 115.82027.
# Coordinates for 529 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 1 Lancaster Road, Wangara, WA fetched. Lat: -31.796743, Lon: 115.815802.
# Coordinates for Albany Highway, Victoria Park, WA fetched. Lat: 47.431768, Lon: -122.227996.
# Coordinates for 196 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 468 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 4 Hocking Road, KINGSLEY, WA fetched. Lat: -31.80094, Lon: 115.81669.
# Coordinates for 435 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.90835, Lon: 115.8103.
# Coordinates for 101 Broun Avenue, Morley, WA fetched. Lat: -31.902026, Lon: 115.904008.
# Coordinates for 19 Davison Street, Maddington, WA fetched. Lat: -32.04286, Lon: 115.98559.
# Coordinates for 3 Salpietro Street, Bibra Lake, WA fetched. Lat: -32.11556, Lon: 115.79544.
# Coordinates for 16 Baretta Road, Wangara, WA fetched. Lat: -31.79241, Lon: 115.82027.
# Coordinates for 16 Baretta Road, Wangara, WA fetched. Lat: -31.79241, Lon: 115.82027.
# Coordinates for 1308 Albany Highway, Cannington, WA fetched. Lat: -32.015497, Lon: 115.931154.
# Coordinates for Albany Highway, Victoria Park, WA fetched. Lat: 47.431768, Lon: -122.227996.
# Coordinates for 4 Hocking Road, KINGSLEY, WA fetched. Lat: -31.80094, Lon: 115.81669.
# Coordinates for 4 Hocking Road, KINGSLEY, WA fetched. Lat: -31.80094, Lon: 115.81669.
# Coordinates for 3 Salpietro Street, Bibra Lake, WA fetched. Lat: -32.11556, Lon: 115.79544.
# Coordinates for 4 Hocking Road, KINGSLEY, WA fetched. Lat: -31.80094, Lon: 115.81669.
# Coordinates for 41 Buckingham Drive, Wangara, WA fetched. Lat: -31.78645, Lon: 115.81995.
# Coordinates for 1261 Albany Highway, Cannington, WA fetched. Lat: -32.012637, Lon: 115.926416.
# Coordinates for 8 Parkland Road, Osborne Park, WA fetched. Lat: -31.91667, Lon: 115.817585.
# Coordinates for 2 Joondalup Drive, Edgewater, WA fetched. Lat: -31.7572029, Lon: 115.7731046.
# Coordinates for 1042 Albany Highway, Saint James, WA fetched. Lat: -31.996515, Lon: 115.914741.
# Coordinates for 17 Luisini Road, Wangara, WA fetched. Lat: -31.79572, Lon: 115.82939.
# Coordinates for 3 Salpietro Street, Bibra Lake, WA fetched. Lat: -32.11556, Lon: 115.79544.
# Coordinates for 41 Buckingham Drive, Wangara, WA fetched. Lat: -31.78645, Lon: 115.81995.
# Coordinates for 196 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 445 Wanneroo Road, Balcatta, WA fetched. Lat: -31.86697, Lon: 115.82846.
# Coordinates for 7 Pembroke Road, Wangara, WA fetched. Lat: -31.797369, Lon: 115.818506.
# Coordinates for 6 Lancaster Road, Wangara, WA fetched. Lat: -31.79716, Lon: 115.81643.
# Coordinates for 101 Stirling Highway, Nedlands, WA fetched. Lat: -31.97905425, Lon: 115.80173020000001.
# Coordinates for 76 Division Street, Welshpool, WA fetched. Lat: -31.987188, Lon: 115.935923.
# Coordinates for 19 Davison Street, Maddington, WA fetched. Lat: -32.04286, Lon: 115.98559.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 3 Salpietro Street, Bibra Lake, WA fetched. Lat: -32.11556, Lon: 115.79544.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 435 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.90835, Lon: 115.8103.
# Coordinates for 2 Joondalup Drive, Edgewater, WA fetched. Lat: -31.7572029, Lon: 115.7731046.
# Coordinates for 77 Buckingham Drive, Wangara, WA fetched. Lat: -31.78773, Lon: 115.82755.
# Coordinates for 324 Collier Road, Bassendean, WA fetched. Lat: -31.906315, Lon: 115.932176.
# Coordinates for 4 Hocking Road, KINGSLEY, WA fetched. Lat: -31.80094, Lon: 115.81669.
# Coordinates for 4 Hocking Road, KINGSLEY, WA fetched. Lat: -31.80094, Lon: 115.81669.
# Coordinates for 468 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 20 Motor Parade, Wangara, WA fetched. Lat: -31.794136, Lon: 115.816569.
# Coordinates for 1261 Albany Highway, Cannington, WA fetched. Lat: -32.012637, Lon: 115.926416.
# Coordinates for 300 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.913327, Lon: 115.824971.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 16 Baretta Road, Wangara, WA fetched. Lat: -31.79241, Lon: 115.82027.
# Coordinates for 468 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 4 Hocking Road, KINGSLEY, WA fetched. Lat: -31.80094, Lon: 115.81669.
# Coordinates for 384 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.91151, Lon: 115.81708.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 1308 Albany Highway, Cannington, WA fetched. Lat: -32.015497, Lon: 115.931154.
# Coordinates for 707 Albany Highway, East Victoria Park, WA fetched. Lat: -31.98209, Lon: 115.90096.
# Coordinates for 1787 Albany Highway, Kenwick, WA fetched. Lat: -32.04529, Lon: 115.97387.
# Coordinates for 2 Joondalup Drive, Edgewater, WA fetched. Lat: -31.7572029, Lon: 115.7731046.
# Coordinates for 324 Collier Road, Bassendean, WA fetched. Lat: -31.906315, Lon: 115.932176.

# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 70-84 Collier Road, Morley, WA fetched. Lat: -31.900748, Lon: 115.903642.
# Coordinates for 1751 Albany Highway, Kenwick, WA fetched. Lat: -32.041921, Lon: 115.971533.
# Coordinates for 162 Leach Highway, Myaree, WA fetched. Lat: -32.04654, Lon: 115.80943.
# Coordinates for 20 Motor Parade, Wangara, WA fetched. Lat: -31.794136, Lon: 115.816569.
# Coordinates for 70-84 Collier Road, Morley, WA fetched. Lat: -31.900748, Lon: 115.903642.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 2 Joondalup Drive, Edgewater, WA fetched. Lat: -31.7572029, Lon: 115.7731046.
# Coordinates for 196 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 7 Sobek Pass, Bibra Lake, WA fetched. Lat: -32.094655, Lon: 115.814641.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 168 Leach Highway, Myaree, WA fetched. Lat: -32.04626, Lon: 115.81017.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 61 Shepperton Road, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 1751 Albany Highway, Kenwick, WA fetched. Lat: -32.041921, Lon: 115.971533.
# Coordinates for 70-84 Collier Road, Morley, WA fetched. Lat: -31.900748, Lon: 115.903642.
# Coordinates for 1287 Albany Highway, Cannington, WA fetched. Lat: -32.0141528, Lon: 115.9274436.
# Coordinates for 1287 Albany Highway, Cannington, WA fetched. Lat: -32.0141528, Lon: 115.9274436.
# Coordinates for 70-84 Collier Road, Morley, WA fetched. Lat: -31.900748, Lon: 115.903642.
# Coordinates for 2A Shepperton Road, Burswood, WA fetched. Lat: -31.969294, Lon: 115.892176.
# Coordinates for 1042 Albany Highway, Saint James, WA fetched. Lat: -31.996515, Lon: 115.914741.
# Coordinates for 6/10 Pembroke Road, Wangara, WA fetched. Lat: -31.7976992, Lon: 115.8175131.
# Coordinates for 170 Leach Highway, Myaree, WA fetched. Lat: -32.046244, Lon: 115.810445.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 70-84 Collier Road, Morley, WA fetched. Lat: -31.900748, Lon: 115.903642.
# Coordinates for 6/10 Pembroke Road, Wangara, WA fetched. Lat: -31.7976992, Lon: 115.8175131.
# Coordinates for 352 Scarborough Beach Road, Osborne Park, WA fetched. Lat: -31.913641, Lon: 115.819898.
# Coordinates for 6 Lancaster Road, Wangara, WA fetched. Lat: -31.79716, Lon: 115.81643.
# Coordinates for 1751 Albany Highway, Kenwick, WA fetched. Lat: -32.041921, Lon: 115.971533.
# Coordinates for 1287 Albany Highway, Cannington, WA fetched. Lat: -32.0141528, Lon: 115.9274436.
# Coordinates for 1888 Albany Highway, Maddington, WA fetched. Lat: -32.054412, Lon: 115.987817.
# Coordinates for 2 Joondalup Drive, Edgewater, WA fetched. Lat: -31.7572029, Lon: 115.7731046.
# Coordinates for 170 Leach Highway, Myaree, WA fetched. Lat: -32.046244, Lon: 115.810445.
# Coordinates for 209 Bannister Road, Canning Vale, WA fetched. Lat: -32.06485, Lon: 115.90025.
# Coordinates for 2 Joondalup Drive, Edgewater, WA fetched. Lat: -31.7572029, Lon: 115.7731046.
# Coordinates for 70-84 Collier Road, Morley, WA fetched. Lat: -31.900748, Lon: 115.903642.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for

# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 170 Welshpool Road, Welshpool, WA fetched. Lat: -31.995227, Lon: 115.938215.
# Coordinates for 9 Carr Place, Myaree, WA fetched. Lat: -32.04511, Lon: 115.81442.
# Coordinates for 10 Lancaster Road, Wangara, WA fetched. Lat: -31.79682, Lon: 115.81737.
# Coordinates for 170 Leach Highway, Myaree, WA fetched. Lat: -32.046244, Lon: 115.810445.
# Coordinates for 196 Albany Highway, Victoria Park, WA fetched. Lat: 47.4558162, Lon: -122.20913610939236.
# Coordinates for 100 Broun Avenue, Morley, WA fetched. Lat: -31.9022587, Lon: 115.9041677.
# Coordinates for Cnr North Lake Road & Leach Hwy, Melville, WA fetched. Lat: -32.040263, Lon: 115.800702.
# Coordinates for Cnr North Lake Road & Leach Hwy, Melville, WA fetched. Lat: -32.040263, Lon: 115.800702.
# Coordinates for Cnr North Lake Road & Leach Hwy, Melville, WA fetched. Lat: -32.040263, Lon: 115.800702.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 324 Collier Road, Bassendean, WA fetched. Lat: -31.906315, Lon: 115.932176.
# Coordinates for 133 Welshpool Road, Welshpool, WA fetched. Lat: -31.995224, Lon: 115.932444.
# Coordinates for 42 Ewing Street, Bentley, WA fetched. Lat: -31.99962, Lon: 115.9236.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
# Coordinates for 8/10 Prindiville Drive, Wangara, WA fetched. Lat: -31.79166, Lon: 115.81549.
#    Year model                                  Car Spec  Kilometres  Price  \
# 1        2019          2019 Hyundai I30 Active PD2 MY19       74070  20998
# 2        2019          2019 Hyundai I30 Active PD2 MY19       66975  21998
# 3        2019          2019 Hyundai I30 Active PD2 MY19       68845  21998
# 4        2017  2017 Mitsubishi Triton GLX (4X4) MQ MY18      188978  24750
# 5        2016  2016 Mitsubishi Triton GLX (4X4) MQ MY16      141855  26900
#
#   Transmission Body type         Drive type        Fuel type  \
# 1    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 2    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 3    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 4    Automatic  Ute tray   Four Wheel Drive           Diesel
# 5    Automatic  Ute tray   Four Wheel Drive           Diesel
#
#    Fuel consumption per 100km Colour ext  ... Fuel tank capacity  \
# 1                         7.4     Silver  ...                 50
# 2                         7.4     Silver  ...                 50
# 3                         7.4     Silver  ...                 50
# 4                         7.6      White  ...                 75
# 5                         7.6      White  ...                 75
#
#   Valve gear type Peak torque (Nm)  Horsepower  Kerb weight        Make  \
# 1              16              203         161         1276     Hyundai
# 2              16              203         161         1276     Hyundai
# 3              16              203         161         1276     Hyundai
# 4              16              430         179         1930  Mitsubishi
# 5              16              430         179         1930  Mitsubishi
#
#     Model    Variant      lat      lon
# 1     I30     Active -32.0167  115.932
# 2     I30     Active -32.0167  115.932
# 3     I30     Active -32.0167  115.932
# 4  Triton  GLX (4X4) -31.9872  115.936
# 5  Triton  GLX (4X4) -31.9872  115.936
#
# [5 rows x 27 columns]

# %%
# Check for null values found in the previous data cleaning exercise
print(df_car_listing.isnull().sum())
# Out:
# Year model                    0
# Car Spec                      0
# Kilometres                    0
# Price                         0
# Transmission                  0
# Body type                     0
# Drive type                    0
# Fuel type                     0
# Fuel consumption per 100km    0
# Colour ext                    0
# VIN                           0
# Dealer                        0
# Address                       0
# Seating capacity              0
# Doors                         0
# CC                            0
# Number of cylinders           0
# Fuel tank capacity            0
# Valve gear type               0
# Peak torque (Nm)              0
# Horsepower                    0
# Kerb weight                   0
# Make                          0
# Model                         0
# Variant                       0
# lat                           0
# lon                           0
# dtype: int64

# %%
# Change lat and lon to float
df_car_listing_complete = df_car_listing.astype({'lat':'float', 'lon': 'float'})
df_car_listing_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2126 entries, 1 to 5669
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year model                  2126 non-null   int64
#  1   Car Spec                    2126 non-null   object
#  2   Kilometres                  2126 non-null   int64
#  3   Price                       2126 non-null   int64
#  4   Transmission                2126 non-null   object
#  5   Body type                   2126 non-null   object
#  6   Drive type                  2126 non-null   object
#  7   Fuel type                   2126 non-null   object
#  8   Fuel consumption per 100km  2126 non-null   float64
#  9   Colour ext                  2126 non-null   object
#  10  VIN                         2126 non-null   object
#  11  Dealer                      2126 non-null   object
#  12  Address                     2126 non-null   object
#  13  Seating capacity            2126 non-null   int64
#  14  Doors                       2126 non-null   int64
#  15  CC                          2126 non-null   int64
#  16  Number of cylinders         2126 non-null   int64
#  17  Fuel tank capacity          2126 non-null   int64
#  18  Valve gear type             2126 non-null   int64
#  19  Peak torque (Nm)            2126 non-null   int64
#  20  Horsepower                  2126 non-null   int64
#  21  Kerb weight                 2126 non-null   Int64
#  22  Make                        2126 non-null   object
#  23  Model                       2126 non-null   object
#  24  Variant                     2126 non-null   object
#  25  lat                         2126 non-null   float64
#  26  lon                         2126 non-null   float64
# dtypes: Int64(1), float64(3), int64(11), object(12)
# memory usage: 467.1+ KB

# %%
# Check datatypes
df_car_listing_complete.dtypes
# Out:
# Year model                      int64
# Car Spec                       object
# Kilometres                      int64
# Price                           int64
# Transmission                   object
# Body type                      object
# Drive type                     object
# Fuel type                      object
# Fuel consumption per 100km    float64
# Colour ext                     object
# VIN                            object
# Dealer                         object
# Address                        object
# Seating capacity                int64
# Doors                           int64
# CC                              int64
# Number of cylinders             int64
# Fuel tank capacity              int64
# Valve gear type                 int64
# Peak torque (Nm)                int64
# Horsepower                      int64
# Kerb weight                     Int64
# Make                           object
# Model                          object
# Variant                        object
# lat                           float64
# lon                           float64
# dtype: object

# %%
# Save the new cleaned dataset
df_car_listing_complete.to_csv('data_cleaning_output/used_cars_dataset_loc.csv', index=False)

# %%
# Filter the dataframe based on the latitude and longitude conditions
lat_condition = -30
filtered_df = df_car_listing_complete[(df_car_listing_complete['lat'] > lat_condition) & (df_car_listing_complete['lon'] < 115)]

# Retrieve the list of addresses from the filtered dataframe
address_list = filtered_df[['Dealer', 'Address']].drop_duplicates().values.tolist()

# Print the list of dealer name and address
for dealer_name, address in address_list:
    print(f"Dealer: {dealer_name}, Address: {address}")
# Out:
# Dealer: Auto Planet WA, Address: 468 Albany Highway, Victoria Park, WA
# Dealer: John Hughes Passenger, Address: 196 Albany Highway, Victoria Park, WA
# Dealer: John Hughes Group - Auto Warehouse, Address: Albany Highway, Victoria Park, WA
# Dealer: Youngs WA, Address: 529 Albany Highway, Victoria Park, WA
# Dealer: John Hughes Commercials, Address: 234 Albany Highway, Victoria Park, WA
# Dealer: John Hughes Group Volkswagen, Address: 61 Shepperton Road, Victoria Park, WA
# Dealer: Cut Price Car Co, Address: 688 Albany Highway, Victoria Park, WA
# Dealer: Perth City Subaru, Address: 165 Albany Highway, Victoria Park, WA
# Dealer: Perth City Prestige, Address: 495 Albany Highway, Victoria Park, WA

# %%
# Manually update the latitude and longitude values for each address
updated_lat_lon = {
    '468 Albany Highway, Victoria Park, WA': (-31.976168, 115.898473),
    '196 Albany Highway, Victoria Park, WA': (-31.9705, 115.89301),
    'Albany Highway, Victoria Park, WA': (-31.970971650000003, 115.89225179909646),
    '529 Albany Highway, Victoria Park, WA': (-31.978105, 115.89843),
    '234 Albany Highway, Victoria Park, WA': (-31.9714252, 115.8939466),
    '61 Shepperton Road, Victoria Park, WA': (-31.970769699999998, 115.89495889583115),
    '688 Albany Highway, Victoria Park, WA': (-31.98124, 115.9013),
    '165 Albany Highway, Victoria Park, WA': (-31.9704221, 115.89155790526316),
    '495 Albany Highway, Victoria Park, WA': (-31.97739, 115.89798),
}

# %%
# Create a copy of the original DataFrame
df_updated = df_car_listing_complete.copy()

# Update the latitude and longitude values in the copied DataFrame
for dealer_name, address in address_list:
    if address in updated_lat_lon:
        new_lat, new_lon = updated_lat_lon[address]
        df_updated.loc[(df_updated['Address'] == address), 'lat'] = new_lat
        df_updated.loc[(df_updated['Address'] == address), 'lon'] = new_lon

# Validate the changes in the new df_updated
df_updated.head()
# Out:
#    Year model                                  Car Spec  Kilometres  Price  \
# 1        2019          2019 Hyundai I30 Active PD2 MY19       74070  20998
# 2        2019          2019 Hyundai I30 Active PD2 MY19       66975  21998
# 3        2019          2019 Hyundai I30 Active PD2 MY19       68845  21998
# 4        2017  2017 Mitsubishi Triton GLX (4X4) MQ MY18      188978  24750
# 5        2016  2016 Mitsubishi Triton GLX (4X4) MQ MY16      141855  26900
#
#   Transmission Body type         Drive type        Fuel type  \
# 1    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 2    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 3    Automatic     Hatch  Front Wheel Drive  Unleaded Petrol
# 4    Automatic  Ute tray   Four Wheel Drive           Diesel
# 5    Automatic  Ute tray   Four Wheel Drive           Diesel
#
#    Fuel consumption per 100km Colour ext  ... Fuel tank capacity  \
# 1                         7.4     Silver  ...                 50
# 2                         7.4     Silver  ...                 50
# 3                         7.4     Silver  ...                 50
# 4                         7.6      White  ...                 75
# 5                         7.6      White  ...                 75
#
#   Valve gear type Peak torque (Nm)  Horsepower  Kerb weight        Make  \
# 1              16              203         161         1276     Hyundai
# 2              16              203         161         1276     Hyundai
# 3              16              203         161         1276     Hyundai
# 4              16              430         179         1930  Mitsubishi
# 5              16              430         179         1930  Mitsubishi
#
#     Model    Variant        lat         lon
# 1     I30     Active -32.016689  115.932215
# 2     I30     Active -32.016689  115.932215
# 3     I30     Active -32.016689  115.932215
# 4  Triton  GLX (4X4) -31.987188  115.935923
# 5  Triton  GLX (4X4) -31.987188  115.935923
#
# [5 rows x 27 columns]

# %%
# Get the list of addresses from the dictionary keys
addresses = list(updated_lat_lon.keys())

# Filter the original DataFrame based on the addresses
filtered_df = df_updated[df_updated['Address'].isin(addresses)]

# Display the filtered addresses, latitude, and longitude
filtered_addresses = filtered_df[['Address', 'lat', 'lon']].drop_duplicates()
filtered_addresses
# Out:
#                                     Address        lat         lon
# 268   468 Albany Highway, Victoria Park, WA -31.976168  115.898473
# 531   196 Albany Highway, Victoria Park, WA -31.970500  115.893010
# 534       Albany Highway, Victoria Park, WA -31.970972  115.892252
# 1086  529 Albany Highway, Victoria Park, WA -31.978105  115.898430
# 1653  234 Albany Highway, Victoria Park, WA -31.971425  115.893947
# 2051  61 Shepperton Road, Victoria Park, WA -31.970770  115.894959
# 2687  688 Albany Highway, Victoria Park, WA -31.981240  115.901300
# 2788  165 Albany Highway, Victoria Park, WA -31.970422  115.891558
# 4838  495 Albany Highway, Victoria Park, WA -31.977390  115.897980

# %%
# Validate datatypes
df_updated.dtypes
# Out:
# Year model                      int64
# Car Spec                       object
# Kilometres                      int64
# Price                           int64
# Transmission                   object
# Body type                      object
# Drive type                     object
# Fuel type                      object
# Fuel consumption per 100km    float64
# Colour ext                     object
# VIN                            object
# Dealer                         object
# Address                        object
# Seating capacity                int64
# Doors                           int64
# CC                              int64
# Number of cylinders             int64
# Fuel tank capacity              int64
# Valve gear type                 int64
# Peak torque (Nm)                int64
# Horsepower                      int64
# Kerb weight                     Int64
# Make                           object
# Model                          object
# Variant                        object
# lat                           float64
# lon                           float64
# dtype: object

# %%
# Rename lat and lon with a capital letter
df_updated = df_updated.rename(columns={'lat': 'Lat', 'lon': 'Lon'})

# Validate data info
df_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2126 entries, 1 to 5669
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year model                  2126 non-null   int64
#  1   Car Spec                    2126 non-null   object
#  2   Kilometres                  2126 non-null   int64
#  3   Price                       2126 non-null   int64
#  4   Transmission                2126 non-null   object
#  5   Body type                   2126 non-null   object
#  6   Drive type                  2126 non-null   object
#  7   Fuel type                   2126 non-null   object
#  8   Fuel consumption per 100km  2126 non-null   float64
#  9   Colour ext                  2126 non-null   object
#  10  VIN                         2126 non-null   object
#  11  Dealer                      2126 non-null   object
#  12  Address                     2126 non-null   object
#  13  Seating capacity            2126 non-null   int64
#  14  Doors                       2126 non-null   int64
#  15  CC                          2126 non-null   int64
#  16  Number of cylinders         2126 non-null   int64
#  17  Fuel tank capacity          2126 non-null   int64
#  18  Valve gear type             2126 non-null   int64
#  19  Peak torque (Nm)            2126 non-null   int64
#  20  Horsepower                  2126 non-null   int64
#  21  Kerb weight                 2126 non-null   Int64
#  22  Make                        2126 non-null   object
#  23  Model                       2126 non-null   object
#  24  Variant                     2126 non-null   object
#  25  Lat                         2126 non-null   float64
#  26  Lon                         2126 non-null   float64
# dtypes: Int64(1), float64(3), int64(11), object(12)
# memory usage: 467.1+ KB

# %%
# Save the final dataset
df_updated.to_csv('data_cleaning_output/used_cars_dataset_complete.csv', index=False)
